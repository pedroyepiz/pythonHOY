# %% [markdown]
# <a href="https://colab.research.google.com/github/pedroyepiz/pythonHOY/blob/main/9_FUNCIONES_EN_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![python portada.png](data:image/png;base64,...)

# %% [markdown]
# # **9.- FUNCIONES EN PYTHON**
#
# Las funciones son bloques de código reutilizables que realizan una tarea específica en un programa. En Python, las funciones son objetos de primera clase, lo que significa que pueden ser asignadas a variables, pasadas como argumentos a otras funciones y devueltas como valores de funciones.
#
# Las funciones son una parte fundamental de la programación en Python, ya que permiten una mayor modularidad y una mejor organización del código. Al dividir un programa en funciones más pequeñas y manejables, se puede facilitar el proceso de desarrollo y mantenimiento de código. Las funciones también permiten la reutilización de código, lo que reduce la duplicación de esfuerzos y mejora la eficiencia del programa.
#
#
# En Python, las funciones pueden recibir argumentos opcionales (por defecto), argumentos posicionales y argumentos con nombre. También pueden devolver valores explícitamente utilizando la palabra clave return.
#
# En resumen, las funciones en Python son bloques de código reutilizables que permiten modularizar el código, facilitar el desarrollo y mantenimiento del programa, reducir la duplicación de esfuerzos y mejorar la eficiencia del programa.

# %% [markdown]
# **Para definir una función en Python, se utiliza la siguiente sintaxis:**
# Las funciones se definen mediante la palabra clave def, seguida del nombre de la función y los parámetros que recibe (si los hay), y terminando con dos puntos (:). El cuerpo de la función se define a continuación, indentado hacia la derecha.
#
# **La sintaxis básica es la siguiente:**
#
# ```
# def nombre_de_la_funcion(parametros):
#     # Cuerpo de la función
#     return valor_de_retorno
# ```

# %% [markdown]
# **Explicación de los elementos de la sintaxis:**
#
# * **`def:`** es una palabra reservada en Python que indica que se está definiendo una función.
# * **`nombre_de_la_funcion:`** es el nombre que le das a la función. Este nombre se utiliza para llamar a la función desde otras partes del programa.
# * **`parametros:`** son los valores que se pasan a la función cuando se llama. Los parámetros son opcionales, por lo que una función también puede no recibir ningún parámetro.
# * **`Código que realiza una tarea:`** es el código que se ejecuta cuando se llama a la función. Este código puede incluir cualquier instrucción válida de Python, como operaciones matemáticas, estructuras de control de flujo, etc.
# * **`return valor_de_retorno:`** es la sentencia return que devuelve un valor opcional como resultado de la función. Si la función no devuelve ningún valor, se puede omitir la sentencia return.

# %% [markdown]
# ![funciones.PNG](data:image/png;base64,...)

# %% [markdown]
# ## **LLAMAR A UNA FUNCION MAIN**

# %%
def nombre():
  print("HOLA MUNDO")
  funcion2()

def funcion2():
  print ("MUNDO CRUEL Y DESPIADADO")

if __name__ == "__main__":
  #funcion2()
  nombre()

# %% [markdown]
# ## **VARIABLE GLOBAL EN  FUNCIONES**

# %%
def suma(n1=0,n2=0):
  suma= n1 + n2
  print("suma.n1--> ",id(n1))
  def salida(valor):
    print (f" la suma es= {valor}")
    global numero
    numero= 45;

  salida(suma)
  n1=12
  print("suma.n1--> ",id(n1))
  return suma

n1=3
n2=4
print("n1--> ",id(n1))
x=suma(n1,n2)
print ("numero:",numero)

# %% [markdown]
# ## **USO DE PARAMETROS EN LAS FUNCIONES CON PYTHON**

# %%
def funcion ():
    pass


funcion()

# %% [markdown]
# ____

# %%
def funcion (num,num2):
  return num+1, num*num2, 23

n3=funcion(2,3)
print (f"  n3= {n3}")
n3 = list(n3)
print (n3)
# Out:
#   n3= (3, 6, 23)
# [3, 6, 23]

# %%
def funcion(*args):
  for i in args:
    print (i)
  print (args)

funcion(4,7,1,9,3,6,7,2,8,3)
# Out:
# 4
# 7
# 1
# 9
# 3
# 6
# 7
# 2
# 8
# 3
# (4, 7, 1, 9, 3, 6, 7, 2, 8, 3)

# %%
def suma(*args):
    resultado = 0
    for numero in args:
        resultado += numero
    return resultado

suma(12,5)
# Out:
# 17

# %% [markdown]
# * Cuando se utiliza `*args` como parámetro en una función en Python, significa que se espera una lista variable de argumentos posicionales, es decir, que la función puede recibir cualquier número de argumentos y tratarlos como una lista.
#
# * El asterisco `*` se utiliza en este caso para indicar que los argumentos que se pasan a la función se deben empaquetar en una tupla. Entonces, cuando la función es llamada, todos los argumentos posicionales adicionales que se pasan después de los parámetros normales de la función se agregan a una tupla y se pasan a la función como un solo argumento.

# %%
def suma(num1,num2):
  suma = num1 + num2
  return suma

x=suma(2,3)
print ("LA SUMA ES= ",suma(5,7))
print ("EL RESULTADO DE X = ",x)
suma(3,6)
# Out:
# LA SUMA ES=  12
# EL RESULTADO DE X =  5
# 9

# %%
def suma(num1=2,num2=2):
  suma = num1 + num2
  return suma

x=suma(3)
print ("LA SUMA ES= ",suma(num2=5))
print ("EL RESULTADO DE X = ",x)
print ("EL RESULTADO  = ",suma(5,5))
suma()
# Out:
# LA SUMA ES=  7
# EL RESULTADO DE X =  5
# EL RESULTADO  =  10
# 4

# %%
def Trapecio(B,b,h):
  area= ((B+b)/2)*h
  return area

area=Trapecio(b=12,B=10,h=4)
print("EL AREAD DEL TRAPECIO ES: ",area)
# Out:
# EL AREAD DEL TRAPECIO ES:  44.0

# %%
def validar(ri=0,rf=100,msge=" DAME UN NUMERO ENTRE ",msgError1="ERROR EN RANGO",msgError2="ERROR DE CAPTURA"):
  while True:
    try:
      num = int(input(f"{msge} {ri} , {rf} : "))
    except:
      print (msgError2)
      continue
    if num < ri or num > rf:
      print (msgError1)
      continue
    return num
# funcion que ahace esto...
def genera(ri,rf):
  from random import randint
  num = randint(ri,rf)
  return num

def juego():
  NumOculto=genera(1,10)
  #print("NUMERO OCULTO: ",NumOculto)
  i=0
  while i<3:
    NumJugador=validar(1,10,"DAME UN NUMERO ENTRE 1 Y 10 : ")
    if NumOculto == NumJugador:
      break 
    else:
      print ("vuelve a intentarlo")
      i=i+1

  if NumOculto == NumJugador:
    print ("FELICIDADES ERES UN GENIO...")
  else:
    print (" HUY NI CON TUS 3 OPORTUNIDADES LE ATINASTE")

juego()
# Out:
# DAME UN NUMERO ENTRE 1 Y 10 :  1 , 10 : 34
# ERROR EN RANGO
# DAME UN NUMERO ENTRE 1 Y 10 :  1 , 10 : 23
# ERROR EN RANGO
# DAME UN NUMERO ENTRE 1 Y 10 :  1 , 10 : 12
# ERROR EN RANGO
# DAME UN NUMERO ENTRE 1 Y 10 :  1 , 10 : 4
# vuelve a intentarlo
# DAME UN NUMERO ENTRE 1 Y 10 :  1 , 10 : 5
# vuelve a intentarlo
# DAME UN NUMERO ENTRE 1 Y 10 :  1 , 10 : 6
# vuelve a intentarlo
#  HUY NI CON TUS 3 OPORTUNIDADES LE ATINASTE

# %% [markdown]
# FUNCIONES EN PYTON

# %%
def triangulo(b=1,h=1):
    return print (f"EL AREA DEL TRIANGULO = ",b*h/2)

def nombre():
  print("HOLA MUNDO")
  funcion()

def funcion():
  print("CRUEL Y DESPIADADO")

def main():
  nombre()
  funcion()

if __name__ == "__main__":
  triangulo(2,4)
# Out:
# EL AREA DEL TRIANGULO =  4.0

# %% [markdown]
# ## **LOS PARAMETROS EN PYTHON PUEDEN SER:**
# ### **POR POSICION**
# ### **VALOR PREDETERMINADO**

# %%
def suma(num1,num2):
  suma=num1+num2
  #print("LA SUMA ES=",suma)
  return suma, num1+num1, "la suma=", True


x=suma(5,2)

print (f" la suma = {x[1]} ")

#print (f" la suma desde la funcion = {suma(3,x)} ")

#print (f" la suma desde la funcion = {suma(3,suma(5,2))} ")
# Out:
#  la suma = 10

# %%
def suma(num1,num2):
  suma=num1+num2
  print (f"num1={num1}   num2={num2}")
  print("LA SUMA ES=",suma)

suma(num2=3,num1=7)
# Out:
# num1=7   num2=3
# LA SUMA ES= 10

# %%
def suma(num1=1,num2=1):
  suma=num1+num2
  print (f"num1={num1}   num2={num2}")
  print("LA SUMA ES=",suma)

suma()
# Out:
#   File "<ipython-input-15-099cf53cb04b>", line 6
#     suma(num2=6,5)
#                ^
# SyntaxError: positional argument follows keyword argument

# %%
def suma(n1=1,n2=1):
  suma=n1+n2
  global numero
  numero =suma
  print ("n1 en suma ->", id(numero))
  def salida (suma):
    print ("la suma es: ",suma)
  salida(suma)
  
  return suma
  
def llamada():
  x=suma(4,3)
  print("LA SUMA ES=",x)

  
x=suma(5,7)
num1=x
num2=num1

print ("x    ->", id(x))
print ("num1 ->", id(num1))
print ("num2 ->", id(num2))
x=suma(2,1)
print ("x    ->", id(x))
# Out:
# n1 en suma -> 93869680462688
# la suma es:  12
# x    -> 93869680462688
# num1 -> 93869680462688
# num2 -> 93869680462688
# n1 en suma -> 93869680462400
# la suma es:  3
# x    -> 93869680462400

# %%
num = 23

def funcion (num=1, num2=1):
    a = 10
    def funcionAnidada ():
        print (a)
        print ("FUNCION ANIDADA")
    
    print (num, num2)
    funcionAnidada()
    return num

cadena=funcion(num2=34)
# Out:
# 1 34
# 10
# FUNCION ANIDADA

# %% [markdown]
# # **try**     except else

# %%
def divide(x, y):
    try:
         result = x / y
    except ZeroDivisionError:
         print("division by zero!")
    else:
         print("result is", result)
    finally:
        print("executing finally clause")

divide(5,1)
# Out:
# result is 5.0
# executing finally clause

# %% [markdown]
# **Los principales excepciones definidas en Python son:**
#
# **TypeError** : Ocurre cuando se aplica una operación o función a un dato del tipo inapropiado.
#
# **ZeroDivisionError** : Ocurre cuando se itenta dividir por cero.
#
# **OverflowError** : Ocurre cuando un cálculo excede el límite para un tipo de dato numérico.
#
# **IndexError** : Ocurre cuando se intenta acceder a una secuencia con un índice que no existe.
#
# **KeyError** : Ocurre cuando se intenta acceder a un diccionario con una clave que no existe.
#
# **FileNotFoundError** : Ocurre cuando se intenta acceder a un fichero que no existe en la ruta indicada.
#
# **ImportError** : Ocurre cuando falla la importación de un módulo.

# %% [markdown]
# **FUNCION QUE SIRVE PARA VALIDAR UN NUMERO DENTRO DE UN RANGO DADO**

# %%
def validar(ri=0,rf=100,msge=" DAME UN NUMERO ENTRE ",msgError1="ERROR EN RANGO",msgError2="ERROR DE CAPTURA"):
  while True:
    try:
      num = int(input(f"{msge} {ri} , {rf} : "))
    except:
      print (msgError2)
      continue
    if num < ri or num > rf:
      print (msgError1)
      continue
    return num

def promedio():
  c1=validar(0,100,"DAME UNA CALIFICACION: ","CALIFICACION NO VALIDA")
  c2=validar(0,100,"DAME UNA CALIFICACION: ","CALIFICACION NO VALIDA")
  c3=validar(0,100,"DAME UNA CALIFICACION: ","CALIFICACION NO VALIDA")
  prom =(c1+c2+c3)/3
  print ("PROMEDIO ES= ",prom)
  edad=validar(18,80,"EADAD DEL TRABAJADOR : EDAD ENTRE- ","EDAD FUERA DE RANGO")
  print("EDAD= ",edad)

promedio()
# Out:
# ERROR DE CAPTURA
# CALIFICACION NO VALIDA
# ERROR DE CAPTURA
# PROMEDIO ES=  37.666666666666664

# %% [markdown]
# PROGRAMA EN PYTHON QUE  GENERE UN NUMERO ENTRE EL 1 Y 10 (NO VISIBLE)   PREGUNTARLE AL USUARIO QUE NUMERO CREE QUE GENERO LA COMPUTADORA,  EL USUARIO TENDRA 3 OPORTUNIDADES DE ADIVINAR.
# DECIR SI ADIVINO O SI FALLO EN SUS 3 INTENTOS.

# %%
lista = [12,23,45,5,7,9,8]
menor = min(lista)
print (menor)
# Out:
# 5

# %%
example_list = [21, 22, 19, 14]

print(max(example_list))
# Out:
# 22
